# %% [markdown]
# # Support vector machine

# %% [markdown]
# - This is best for classification
# - works better in classification
# - Also use this for regression
# - But this model does not work better in regression

# %% [markdown]
# ---

# %% [markdown]
# Classification

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report,confusion_matrix

# %% [markdown]
# `Load Dataset`

# %%
# load dataset
df=sns.load_dataset('iris')
print(df.shape)
# Out:
# (150, 5)

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# `Statistical analysis`

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates().inplace=True

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# `Graphical representation`

# %%
sns.scatterplot(df)
plt.title("iris_dataset")
plt.show()

# %%
sns.barplot(x=df["species"],y=df["sepal_length"],color="gray")
plt.title("sepecies and sepal-lenght")
plt.xlabel("species")
plt.ylabel("sepal-lenght")
plt.show()

# %%
sns.barplot(x=df["species"],y=df["sepal_width"],color="black")
plt.title("sepecies and sepal_width")
plt.xlabel("species")
plt.ylabel("sepal_width")
plt.show()

# %%
sns.barplot(x=df["species"],y=df["petal_width"],color="gray")
plt.title("sepecies and petal_width")
plt.xlabel("species")
plt.ylabel("petal_width")
plt.show()

# %%
sns.barplot(x=df["species"],y=df["petal_length"],color="gray")
plt.title("sepecies and petal_length")
plt.xlabel("species")
plt.ylabel("petal_length")
plt.show()

# %% [markdown]
# `Feature Selection`

# %%
x=df.drop('species',axis=1)
y=df['species']

# %% [markdown]
# - `train test split`
# - `fit model`

# %%
# train test split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# call the model
model=SVC(kernel='rbf')
model.fit(x_train,y_train)
y_pred=model.predict(x_test)

# %% [markdown]
# `metrics`

# %%
print('Confusion_matrix:\n',confusion_matrix(y_test,y_pred))
print("=========================")
print("Classification_report:\n",classification_report(y_test,y_pred))
# Out:
# Confusion_matrix:
#  [[10  0  0]
#  [ 0  9  0]
#  [ 0  0 11]]
# ...
# Classification_report:
#                precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        10
#   versicolor       1.00      1.00      1.00         9
#    virginica       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %% [markdown]
# `Heatmap`

# %%
sns.heatmap(confusion_matrix(y_test,y_pred),annot=True)
plt.xlabel('Prediction')
plt.ylabel('Truth')
# Out:
# Text(50.722222222222214, 0.5, 'Truth')
