# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.linear_model import LinearRegression

# %%
# d=sns.load_dataset('diamonds')
# d.head()

# %%
df=pd.read_csv('C:\\Users\\HP\\OneDrive\\Documentos\\python\\jupyter_note_book\\ml\\machine_learning.csv')

# %%
df.head()
# Out:
#    customer_id  age  purchase_amount loyalty_status activity_date
# 0            1   34            56.78           Gold    2024-01-15
# 1            2   28           123.45         Silver    2024-01-16
# 2            3   45            12.99         Bronze    2024-01-17
# 3            4   22           200.00           Gold    2024-01-18
# 4            5   50            75.20         Bronze    2024-01-19

# %%
sns.lmplot(x='customer_id',y="age",data=df)

# %%
x=df[["customer_id"]]
y=df["age"]
z=df['purchase_amount']

model=LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.predict([[101]])
# Out:
# C:\Users\HP\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([37.63212121])

# %%
# Predict age on the bases of customer_id and purchase_amount

x=df[["customer_id",'purchase_amount']]
y=df["age"]

model=LinearRegression()
model.fit(x,y)

model.predict([[101,133.8]])
# Out:
# C:\Users\HP\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([36.16201984])
